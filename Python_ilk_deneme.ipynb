# %%
print("Hello World")
# Out:
# Hello World

# %%
#print("Selam Dünya")

# %%
import sys  # import python programlama dilinde yazılıma kütüphane eklemeye yarıyan kod bloğudur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
# !pwd   # bize kodun çıktısını dosya yolu olarak veren kod bloğudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
